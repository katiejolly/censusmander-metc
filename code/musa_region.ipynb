# %%
# %matplotlib inline
import pysal as ps
import numpy as np
import pandas as pd
import geopandas as gp
import shapely
import copy
import random
import acs_regionalization as ACS
import matplotlib.pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 20,20  #set the default map size
#rcParams['patch.linewidth'] = 0.5  #set default polygon line width

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # print all output, not just last
# Out:
# C:\Users\JollyKD\AppData\Local\Continuum\anaconda2\lib\site-packages\pysal\__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)

# %%
# read in the Ramsey shapefile and plot it   
shp_map = gp.read_file('metc_data/target/bg_musa.shp')
shp_map['constant'] = 1
p = shp_map.plot('constant', alpha=0.5, cmap='winter')
p.axis('off')
p.plot()
# Out:
# (425208.58528319787, 525024.7025745992, 4927497.086270792, 5033811.143481896)
# []

# %%
# read spatial data into python and run some diagnostics
w = ps.rook_from_shapefile('metc_data/target/bg_musa.shp', idVariable='GEOID')
print w.n   # number of block groups = 2001
# Out:
# 2001

# %%
# summary of the connectivity structure of the MUSA block groups
w_hist_data = np.array(w.histogram)
fig, ax = plt.subplots(figsize=(5,5))
ax.bar(w_hist_data[:,0], w_hist_data[:,1], align='center', width=1)
ax.set_xlabel('number of neighbors')
ax.set_ylabel('number of block groups')
# shows, for example, that ~600 block groups have 5 neighbors
# Out:
# <BarContainer object of 14 artists>
# Text(0.5,0,'number of neighbors')
# Text(0,0.5,'number of block groups')

# %%
# read in list of census tracts to exclude
exclude = open('metc_data/target/exclude_musa.csv')
exclude = exclude.readline()
exclude = exclude.replace('g','')
exclude = exclude.split(',')
print exclude
# Out:
# ['271239800001']

# %%
# read in the ACS estimates and standard errors
population = pd.read_csv('metc_data/target/target_population_musa.csv', index_col=0)

population.shape
population.head

est_prop = pd.read_csv('metc_data/target/target_estimates_musa2var.csv', index_col=0)

est_prop.head
moe_prop = pd.read_csv('metc_data/target/target_moe_musa2var.csv', index_col=0)
# Out:
# (2001, 1)
# <bound method DataFrame.head of               totalppl
# id
# 270030501091      1735
# 270030501092      1124
# 270030501093      1128
# 270030501094      1293
# 270030501101      1306
# 270030501102      1347
# 270030501111      1553
# 270030501112      1800
# 270030501113       447
# 270030502081      1621
# 270030502082      1730
# 270030502101      1122
# 270030502102      1150
# 270030502103       883
# 270030502104       854
# 270030502191      1292
# 270030502192      1661
# 270030502201      2238
# 270030502202      1645
# 270030502203      1260
# 270030502204      1926
# 270030502211      2055
# 270030502212      1279
# 270030502213      3941
# 270030502221      1328
# 270030502222      1052
# 270030502223      1330
# 270030502224      1733
# 270030502231      2874
# 270030502241       802
# ...                ...
# 271630710133      1509
# 271630710141      2739
# 271630710142      1433
# 271630710151      2013
# 271630710152      2365
# 271630710153      2394
# 271630710161      1904
# 271630710162      2700
# 271630710171      8111
# 271630710181      7503
# 271630710182      9164
# 271630712061      7423
# 271630712062      1388
# 271630712063      2085
# 271630712071      2189
# 271630712072      2819
# 271630712073      1826
# 271630712081      1489
# 271630712082      2046
# 271630712083      1615
# 271630712091      2603
# 271630712092      1923
# 271630712093      1469
# 271630713001      2682
# 271630713002      2694
# 271630714001       796
# 271630714002      1103
# 271630714003      1012
# 271630714004      2345
# 271630714005      2032
#
# [2001 rows x 1 columns]>
# <bound method DataFrame.head of               totalwhite  totalppl  over65  total65
# id
# 270030501091        1663      1735     173     1735
# 270030501092        1046      1124      96     1124
# 270030501093        1057      1128     161     1128
# 270030501094        1218      1293     144     1293
# 270030501101        1292      1306     108     1306
# 270030501102        1203      1347     130     1347
# 270030501111        1519      1553     102     1553
# 270030501112        1690      1800     248     1800
# 270030501113         447       447      63      447
# 270030502081        1291      1621     299     1621
# 270030502082        1334      1730      18     1730
# 270030502101        1053      1122     120     1122
# 270030502102        1017      1150     135     1150
# 270030502103         883       883     215      883
# 270030502104         707       854     148      854
# 270030502191        1245      1292     191     1292
# 270030502192        1352      1661     219     1661
# 270030502201        2064      2238     110     2238
# 270030502202        1369      1645     270     1645
# 270030502203        1153      1260     267     1260
# 270030502204        1535      1926      87     1926
# 270030502211        1870      2055     316     2055
# 270030502212        1195      1279     132     1279
# 270030502213        3781      3941     201     3941
# 270030502221        1192      1328      52     1328
# 270030502222         962      1052     115     1052
# 270030502223        1175      1330      58     1330
# 270030502224        1488      1733     220     1733
# 270030502231        2673      2874     343     2874
# 270030502241         780       802     100      802
# ...                  ...       ...     ...      ...
# 271630710133        1363      1509     156     1509
# 271630710141        2221      2739     334     2739
# 271630710142        1236      1433      64     1433
# 271630710151        1539      2013      68     2013
# 271630710152        2005      2365     218     2365
# 271630710153        1800      2394     530     2394
# 271630710161        1567      1904     323     1904
# 271630710162        2243      2700     110     2700
# 271630710171        5555      8111     838     8111
# 271630710181        5784      7503     434     7503
# 271630710182        6459      9164     770     9164
# 271630712061        5424      7423     579     7423
# 271630712062        1139      1388     128     1388
# 271630712063        1596      2085     201     2085
# 271630712071        2122      2189     372     2189
# 271630712072        2380      2819     200     2819
# 271630712073        1465      1826      96     1826
# 271630712081        1266      1489     219     1489
# 271630712082        1738      2046     339     2046
# 271630712083        1196      1615     201     1615
# 271630712091        2195      2603     223     2603
# 271630712092        1380      1923      85     1923
# 271630712093        1313      1469     102     1469
# 271630713001        2136      2682     275     2682
# 271630713002        2286      2694     298     2694
# 271630714001         696       796     133      796
# 271630714002         945      1103     230     1103
# 271630714003         840      1012     255     1012
# 271630714004        1819      2345     163     2345
# 271630714005        1555      2032     309     2032
#
# [2001 rows x 4 columns]>

# %%
# EXCLUDE PLACES WITH ZERO POPULATION

shp = ps.open('metc_data/target/bg_musa.shp')
random.seed(789)     # to ensure we get the same solution each time
np.random.seed(789)  # to ensure we get the same solution each time
results = ACS.ACS_Regions(w=w,\
                          target_est_prop=est_prop.values,\
                          target_moe_prop=moe_prop.values,\
                          count_est=population.values,\
                          target_th_all = 0.15,\
                          exclude=exclude,\
                          compactness=shp,\
                          cv_exclude_prop=0.05)
print 'regionalization finished'
# Out:
# acs_regionalization.py:462: RuntimeWarning: divide by zero encountered in divide
#   ssd_improvement = (end_ssds - start_ssds) / start_ssds
# acs_regionalization.py:462: RuntimeWarning: invalid value encountered in divide
#   ssd_improvement = (end_ssds - start_ssds) / start_ssds
# acs_regionalization.py:646: RuntimeWarning: divide by zero encountered in divide
#   cvs = sdes / ests    # we bypass the cv_exclude rules for the output
# acs_regionalization.py:617: RuntimeWarning: invalid value encountered in divide
#   cv = sdes / ests    # we bypass the cv_exclude rules for the output
# acs_regionalization.py:617: RuntimeWarning: divide by zero encountered in divide
#   cv = sdes / ests    # we bypass the cv_exclude rules for the output
# regionalization finished

# %%
print 'number of regions:', len(results.regions)
print 'total time (seconds):', results.time['total']
# Out:
# number of regions: 715
# total time (seconds): 8071.24899983

# %%
# We'll make a few side-by-side plots. This code wraps the setup into a function.
def two_plot_setup():
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(40,40))
    axes[0].set_aspect('equal')
    axes[1].set_aspect('equal')
    axes[0].axis('off')
    axes[1].axis('off')
    return fig, axes

fig, axes = two_plot_setup()

# color tracts based on region ID
rids = copy.copy(results.region_ids)
shp_map['rids'] = rids
shp_map.plot('rids', categorical=True, alpha=1, colormap='Set3', axes=axes[0])

# disolve the tracts into regions
region_groups = shp_map.groupby('rids')
region_map = gp.GeoDataFrame(index=region_groups.indices.keys())
region_map['rids'] = region_groups.indices.keys()
region_map['geometry'] = region_groups.geometry.apply(shapely.ops.unary_union)
region_map.plot('rids', categorical=True,  colormap='Set3', axes=axes[1])
# Out:
# C:\Users\JollyKD\AppData\Local\Continuum\anaconda2\lib\site-packages\geopandas\plotting.py:381: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# C:\Users\JollyKD\AppData\Local\Continuum\anaconda2\lib\site-packages\geopandas\plotting.py:385: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   "(for consistency with pandas)", FutureWarning)

# %%
shp_map.to_file("output/musa_2var_cv15.shp")
